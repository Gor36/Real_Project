# %% [markdown]
# Вы выполнили проект по кластеризации данных — поздравляем!
#
# После завершения оформления проекта на GitHub прикрепите ссылку на репозиторий со своим проектом в форму ниже. Ментор выставит оценку за работу и даст обратную связь.
#
# # **Критерии оценивания:**
#
# ## **Кейс «Сегментация клиентов онлайн-магазина подарков» (максимум — 18 баллов)**
#
# 1. Знакомство со структурой данных (2 балла)
#
# Описание критерия |	Баллы
# ---- | ----
# Студент произвёл базовый (первичный) анализ структуры исходных данных, нашёл основные статистические характеристики признаков, привёл первичные выводы о структуре данных и их особенностях.|	2
# Студент произвёл базовый анализ исходных данных, однако первичные выводы о данных либо не приведены, либо не соответствуют действительности.|	1
# Базовый анализ данных не произведён.|	0
#
# 2. Преобразование, очистка и анализ данных (5 баллов)
#
# 2.1. Преобразование и очистка данных о транзакциях
#
# Описание критерия|	Баллы
# ---- | ----
# Выполнены все необходимые элементы преобразования и очистки данных:|	2
# * Найдены и обработаны (удалены) пропуски.
# * Найдены и обработаны (удалены) дубликаты.
# * Для каждой транзакции рассчитано количество возвращённого впоследствии товара.
# * Найдены и удалены транзакции с отрицательным количеством товара.
# * Найдены и удалены все специализированные транзакции.
# * Найдены и удалены транзакции, в которых присутствуют бесплатные товары.
# * Для каждой транзакции рассчитана общая стоимость товаров.
# Примечание. Возможно наличие иных преобразований данных, не указанных в списке и обеспечивающих повышение качества итогового результата.
# Студент выполнил только важнейшую часть из заявленных преобразований данных, которая существенно влияет на итоговый результате кластеризации.|	1
# Необходимые преобразования данных не выполнены либо выполнены некорректно.|	0
#
# ## **2.2. Разведывательный анализ данных о транзакциях**
#
# Описание критерия	Баллы
# Студент выполнил разведывательный анализ данных, сопроводил свои рассуждения визуализацией, привёл корректные выводы по полученным результатам и подкрепил свои выводы статистическими тестами (там, где это необходимо).	2
# Студент выполнил разведывательный анализ данных, сопроводил свои рассуждения визуализацией, но сделал это формально, не дополнив визуализации выводами и рассуждениями.	1
# Студент не произвёл разведывательный анализ данных.	0
#
# **2.3. Построение RFM-таблицы и поиск RFM-выбросов**
# Описание критерия	Баллы
# Студент корректно построил RFM-таблицу для клиентов на основе исходных данных о транзакциях, а также нашёл в ней наблюдения-выбросы и избавился от них.	1
# Студент не построил RFM-таблицу или сделал это некорректно, что значительно исказило полученные в дальнейшем результаты.	0
# Моделирование и оценка качества модели (7 баллов)
#
# **3.1. Кластеризация на основе RFM-характеристик** (проверяется только при условии, что за критерий 2.3. не выставлено 0 баллов)
# Описание критерия	Баллы
# На основе полученной RFM-таблицы студент провёл качественную сегментацию клиентов:
# применил несколько (не менее трёх) методов кластеризации и понижения размерности;
# произвёл разделение пользователей онлайн-магазина на сегменты, подобрал оптимальное количество кластеров;
# выбрал оптимальный по внутренним мерам алгоритм.
#
# **3**
#
# Студент провёл сегментацию клиентов, не допустив значительных ошибок, влияющих на корректность полученных выводов, однако применил недостаточно методов кластеризации (менее трёх).
#
# Либо студент провёл сегментацию клиентов, однако допустил ошибки, незначительно влияющие на корректность полученных выводов.	2
# Студент провёл сегментацию клиентов, однако сделал это только формально, не сравнив несколько методов кластеризации, не подобрав оптимальное количество кластеров.	1
# Студент не произвёл сегментацию клиентов или сделал это некорректно.	03.2. Интерпретация кластеров
#
# 3.2.1. Визуализация кластеров
# Описание критерия	Баллы
# Студент представил результаты кластеризации в двух- или трёхмерном пространстве и сопроводил полученные графики выводами о качестве кластеризации.	2
# Студент представил результаты кластеризации в двух- или трёхмерном пространстве, однако сделал это только формально, не сопроводив полученные диаграммы выводами.	1
# Студент не произвёл визуализацию кластеров.	03.2.2. Построение профиля кластеров
# Описание критерия	Баллы
# Студент построил профили кластеров, визуализировал их в виде понятной диаграммы, а также привёл корректную интерпретацию полученных кластеров.	2
# Студент построил профили кластеров, визуализировал их в виде понятной диаграммы, но интерпретация некоторых полученных кластеров выполнена некорректно, однако это несущественно влияет на качество решения задачи.	1
# Студент не построил профили и не проинтерпретировал кластеры, либо интерпретация некоторых полученных кластеров выполнена некорректно, и это существенно влияет на качество решения задачи.	0
# Выводы и оформление репозитория (2 балла)
# Описание критерия	Баллы
# Студент разместил проект в виде репозитория на GitHub, привёл описание к проекту в требуемом формате в виде файла README.md, где также указал финальные выводы по проделанной работе.	2
# Студент разместил проект в виде репозитория на GitHub, привёл описание к проекту в требуемом формате в виде файла README.md, но не указал финальные выводы по проделанной работе.	1
# Студент разместил проект в виде репозитория на GitHub, но привёл только исходный код, без описания к нему.	0
# Оформление кода (2 балла)
# Описание критерия	Баллы
# Код студента чистый и понятный, оформлен по стандартам PEP-8, сопровождён комментариями и/или имеет документацию.	2
# Код студента содержит дублирующийся код/не сопровождён комментариями и не имеет документации, но доступен для чтения.	1
# Код студента содержит много дублирующегося кода, что сильно усложняет его чтение и работу/не доступен для чтения, не сопровождён комментариями и не имеет документации.	0
# Кейс «Кластеризация изображений транспортных средств» от IntelliVision (максимум — 18 баллов)
# Знакомство со структурой данных (2 балла)
# Описание критерия	Баллы
# Студент корректно прочитал исходные данные и произвёл базовый (первичный) анализ структуры исходных данных, привёл первичные выводы о структуре данных (размерностях используемых дескрипторов) и их особенностях.	2
# Студент корректно прочитал исходные данные и произвёл базовый (первичный) анализ структуры исходных данных, однако первичные выводы о структуре данных (размерностях используемых дескрипторов) и их особенностях либо не приведены, либо не соответствуют действительности.	1
# Базовый анализ данных не произведён.	0
# Преобразование, очистка и анализ данных (5 баллов)
# Описание критерия	Баллы
# Студент корректно выполнил понижение размерности признакового пространства для каждого варианта дескрипторов, подобрав и обосновав оптимальное количество компонент нового признакового пространства.
#
# Либо студент не стал выполнять понижение размерности признакового пространства, обосновав своё решение, и в дальнейшем получил качественные результаты кластеризации без потери производительности.	5
# Студент выполнил понижение размерности признакового пространства, но не обосновал свой выбор количества компонент.	3
# Студент пропустил этап преобразования размерности исходных данных и не обосновал своего решения.	0
# Моделирование и оценка качества модели (7 баллов)
#
# 3.1. Кластеризация изображений
# Описание критерия	Баллы
# Студент выполнил кластеризацию изображений на основе каждого варианта дескрипторов с помощью нескольких алгоритмов (не менее трёх), подобрал оптимальное количество кластеров, указал выбранные им метрики и их интерпретацию, а также плюсы и минусы для каждого применённого алгоритма.	3
# Студент выполнил кластеризацию изображений на основе каждого варианта дескрипторов с помощью двух и менее алгоритмов, но подобрал оптимальное количество кластеров, указал выбранные им метрики и их интерпретацию, а также плюсы и минусы для каждого применённого алгоритма.	2
# Студент выполнил кластеризацию на основе каждого варианта дескрипторов, но сделал это только формально, не обосновав выбора алгоритма и не подобрав оптимальное количество кластеров.	1
# Студент не выполнил кластеризацию на основе дескрипторов или сделал это неверно, что не позволяет корректно производить интерпретацию результатов кластеризации.	03.2. Интерпретация кластеров (критерий проверяется при условии, что за критерий 3.1. не выставлено 0 баллов)
#
# 3.2.1. Визуализация кластеров
# Описание критерия	Баллы
# Студент произвёл понижение размерности каждого варианта дескрипторов с помощью соответствующих алгоритмов, представил результаты кластеризации в двух- или трёхмерном пространстве и сопроводил полученные графики выводами о качестве кластеризации.	2
# Студент произвёл понижение размерности каждого варианта  дескрипторов с помощью алгоритма t-SNE и представил результаты кластеризации в двух- и трёхмерном пространстве, но не сопроводил полученные графики выводами о качестве кластеризации.	1
# Студент не произвёл визуализацию полученных кластеров.	03.2.2. Визуализация изображений в кластере
# Описание критерия	Баллы
# Студент визуализировал несколько изображений из каждого кластера для каждого варианта дескрипторов и на основе полученной визуализации сделал корректные выводы о профиле каждого из кластеров.	1
# Студент не визуализировал несколько изображений из каждого кластера ни для одного варианта дескрипторов либо сделал это некорректно, и это существенно влияет на качество решения задачи.	03.3. Поиск выбросов
# Описание критерия	Баллы
# Студент произвёл поиск выбросов в исходных данных (алгоритм поиска автоматизирован), визуализировал наблюдения, помеченные как выбросы, и привёл интерпретацию полученных результатов.	1
# Студент не попытался найти выбросы в данных или произвёл ручной поиск выбросов в исходных данных, и полученное им решение нельзя автоматически применить на новых данных.	0
# Выводы и оформление репозитория (2 балла)
# Описание критерия	Баллы
# Студент разместил свой проект в виде репозитория на GitHub, привёл описание к нему в требуемом формате в виде файла README.md, где также указал финальные выводы по проделанной работе, отметив финальные результаты кластеризации и рекомендации по использованию исходных дескрипторов.	2
# Студент разместил свой проект в виде репозитория на GitHub, привёл описание к нему в требуемом формате в виде файла README.md, но не указал финальные выводы по проделанной работе.	1
# Студент разместил свой проект в виде репозитория на GitHub, но привёл только исходный код, без описания к нему.	0
# Оформление кода (2 балла)
# Описание критерия	Баллы
# Код студента чистый и понятный, оформлен по стандартам PEP-8, сопровождён комментариями и/или имеет документацию.	2
# Код студента содержит дублирующийся код/не сопровождён комментариями и не имеет документации, но доступен для чтения.	1
# Код студента содержит много дублирующегося кода, что сильно усложняет его чтение и работу/не доступен для чтения, не сопровождён комментариями и не имеет документации.	0
# Задание, оцениваемое ментором
# Задание 4.1 (PJ-03)
# Домашнее задание проверит ментор и поставит оценку. Если возникнут сложности, обращайтесь в канал модуля. Желаем успехов! ;)
